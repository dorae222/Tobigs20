# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn')
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %% [markdown]
# # Data

# %%
"""
    sklearn 당뇨병 진행도 데이터

    <x>
    Age
    Sex
    Body mass index
    Average blood pressure
    S1 : 혈청에 대한 6가지 지표들
    S2
    S3
    S4
    S5
    S6
    
    *데이터가 각 컬럼의 합이 1이 되도록 centering, scaling 되어 있습니다 
    
    
    <y> 
    target: a quantitative measure of disease progression one year after baseline

"""
# Out:
# '\n    sklearn 당뇨병 진행도 데이터\n\n    <x>\n    Age\n    Sex\n    Body mass index\n    Average blood pressure\n    S1 : 혈청에 대한 6가지 지표들\n    S2\n    S3\n    S4\n    S5\n    S6\n    \n    *데이터가 각 컬럼의 합이 1이 되도록 centering, scaling 되어 있습니다 \n    \n    \n    <y> \n    target: a quantitative measure of disease progression one year after baseline\n\n'

# %%
# Data Load 
from sklearn import datasets
diabetes = datasets.load_diabetes()

X = pd.DataFrame(diabetes.data)
y = pd.Series(diabetes.target)
data = pd.concat([X,y], axis = 1)
data.columns = ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'target']

# %%
data.head()
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019908 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068330 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005671  ... -0.002592  0.002864 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  ...  0.034309  0.022692 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  ... -0.002592 -0.031991 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (442, 11)

# %% [markdown]
# ## 1. Data Description

# %%
# 결측치 체크 
data.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
# data type 체크 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
data.describe()
# Out:
#                 age           sex  ...            s6      target
# count  4.420000e+02  4.420000e+02  ...  4.420000e+02  442.000000
# mean  -3.634285e-16  1.308343e-16  ... -3.412882e-16  152.133484
# std    4.761905e-02  4.761905e-02  ...  4.761905e-02   77.093005
# min   -1.072256e-01 -4.464164e-02  ... -1.377672e-01   25.000000
# 25%   -3.729927e-02 -4.464164e-02  ... -3.317903e-02   87.000000
# 50%    5.383060e-03 -4.464164e-02  ... -1.077698e-03  140.500000
# 75%    3.807591e-02  5.068012e-02  ...  2.791705e-02  211.500000
# max    1.107267e-01  5.068012e-02  ...  1.356118e-01  346.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ## 2. Target distribution

# %%
figure, (ax1, ax2) = plt.subplots(ncols=2)
figure.set_size_inches(12,4)

sns.boxplot(data["target"], ax=ax1)
sns.distplot(data[["target"]],ax=ax2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * target 분포는 나름 정규분포의 향상을 보이고 있어요 (skewed 되어 있으면 log Transformation 등의 조치를 취해 주어야 함)
# * 이상점은 없는 것 처럼 보이네요 !

# %%
# 회귀분석 기본 가정 검토 : 선형성 
sns.pairplot(data)

# %% [markdown]
# * s4의 경우 조금 의심가기는 하지만,
# * 대부분의 변수들이 선형성을 만족하고 있다고 할 수 있어요

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 1. Categorical Variable

# %%
data["sex"].unique()
# Out:
# array([ 0.05068012, -0.04464164])

# %%
dummy = pd.get_dummies(data.sex)
dummy.columns=['sex0','sex1']
dummy.head()
# Out:
#    sex0  sex1
# 0     0     1
# 1     1     0
# 2     0     1
# 3     1     0
# 4     1     0

# %%
data = pd.concat([data, dummy], axis=1)
data = data.drop(['sex'], axis=1)
data.head()
# Out:
#         age       bmi        bp        s1  ...        s6  target  sex0  sex1
# 0  0.038076  0.061696  0.021872 -0.044223  ... -0.017646   151.0     0     1
# 1 -0.001882 -0.051474 -0.026328 -0.008449  ... -0.092204    75.0     1     0
# 2  0.085299  0.044451 -0.005671 -0.045599  ... -0.025930   141.0     0     1
# 3 -0.089063 -0.011595 -0.036656  0.012191  ... -0.009362   206.0     1     0
# 4  0.005383 -0.036385  0.021872  0.003935  ... -0.046641   135.0     1     0
#
# [5 rows x 12 columns]

# %% [markdown]
# ## 2. 변수들 간의 상관관계

# %%
X = data.drop(['target'], axis=1)
y = data.target

# %%
# correlation matrix 
X.corr()
# Out:
#            age       bmi        bp  ...        s6      sex0      sex1
# age   1.000000  0.185085  0.335427  ...  0.301731 -0.173737  0.173737
# bmi   0.185085  1.000000  0.395415  ...  0.388680 -0.088161  0.088161
# bp    0.335427  0.395415  1.000000  ...  0.390429 -0.241013  0.241013
# s1    0.260061  0.249777  0.242470  ...  0.325717 -0.035277  0.035277
# s2    0.219243  0.261170  0.185558  ...  0.290600 -0.142637  0.142637
# s3   -0.075181 -0.366811 -0.178761  ... -0.273697  0.379090 -0.379090
# s4    0.203841  0.413807  0.257653  ...  0.417212 -0.332115  0.332115
# s5    0.270777  0.446159  0.393478  ...  0.464670 -0.149918  0.149918
# s6    0.301731  0.388680  0.390429  ...  1.000000 -0.208133  0.208133
# sex0 -0.173737 -0.088161 -0.241013  ... -0.208133  1.000000 -1.000000
# sex1  0.173737  0.088161  0.241013  ...  0.208133 -1.000000  1.000000
#
# [11 rows x 11 columns]

# %%
# heatmap : correlation matrix 시각화 
plt.figure(figsize=(10,10))
sns.heatmap(data = X.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
# 변수들 사이의 pairplot 
sns.pairplot(X)

# %% [markdown]
# * s1, s2는 높은 선형 관계를 보이고 있어요
# * s5, s6의 경우 상관계수는 0.46 이지만, 산점도를 보았을 때 선형 관계를 띄고 있다고 볼 수 있으므로 한번 체크해 보기로 합시다 !

# %%
# VIF check 
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif.sort_values(["VIF Factor"], ascending=[False])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#     VIF Factor features
# 3    59.203786       s1
# 4    39.194379       s2
# 5    15.402352       s3
# 7    10.076222       s5
# 6     8.890986       s4
# 1     1.509446      bmi
# 8     1.484623       s6
# 2     1.459429       bp
# 0     1.217307      age
# 10    1.147844     sex1
# 9     1.130229     sex0

# %% [markdown]
# * 다중공선성 의심 변수 : s1, s2, s3, s5
# * 다중공선성이 의심가는 변수를 제거해 가며 모델을 판단해 보기로 합니다 (10이상)

# %%
X2 = X.drop(['s1'], axis=1)

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif["features"] = X2.columns
vif.sort_values(["VIF Factor"], ascending=[False])
# Out:
#    VIF Factor features
# 5    7.818675       s4
# 4    3.736893       s3
# 3    2.926545       s2
# 6    2.172865       s5
# 1    1.502327      bmi
# 7    1.484410       s6
# 2    1.457415       bp
# 0    1.216892      age
# 9    1.146237     sex1
# 8    1.128813     sex0

# %% [markdown]
# * s1 변수를 제거했더니, 다중공선성 문제가 해결되었네요 ^_^

# %% [markdown]
# ## 3. target 변수와의 상관관계

# %%
data.corr()['target'].sort_values(ascending=False)
# Out:
# target    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441484
# s4        0.430453
# s6        0.382483
# s1        0.212022
# age       0.187889
# s2        0.174054
# sex1      0.043062
# sex0     -0.043062
# s3       -0.394789
# Name: target, dtype: float64

# %% [markdown]
# * 여기서 상관관계가 지나치게 높게 나타나면 해당 변수의 영향력이 너무 지나치게 크다고 판단할 수 있는데,
# * 현 상황에서는 괜찮아 보여요 !

# %% [markdown]
# # Modeling

# %% [markdown]
# > 1. from sklearn.linear_model import LinearRegression
# > 2. import statsmodels.api as sm

# %% [markdown]
# ## 1. sklearn LinearRegression

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso

from sklearn.metrics import mean_squared_error

# %%
# train test split 
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.2, random_state=0)

# %%
# 모델 불러옴
model = LinearRegression()

# train data에 fit시킴
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# predict
pred = model.predict(X_train)

# %%
# fit된 모델의 R-square
model.score(X_train, y_train)
# Out:
# 0.5509511284994073

# %%
mean_squared_error(y_train, pred)
# Out:
# 2752.9828559505945

# %%
print(model.coef_) # 추정된 회귀계수 (intercept제외)
print(model.intercept_) # intercept
# Out:
# [ -32.02315078  573.1051329   297.36444115 -187.58783731 -279.76186988
#    63.63991541  487.63633543   45.40157191   11.3789958   -11.3789958 ]
# 151.6777114152612

# %%
# test data R-square
model.score(X_test, y_test)
# Out:
# 0.3235080332827154

# %%
# 예측 vs 실제 데이터 plot
plt.plot(y_test, model.predict(X_test), '.')

# 예측과 실제가 비슷하면, 라인상에 분포함
x = np.linspace(0, 330, 100)
y = x
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Ridge, Lasso Regression

# %%
ridge = Ridge(alpha=1.0) # alpha: 정규화의 정도를 결정해주는 하이퍼파라미터 (클수록 더 정규화)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# R-square
ridge.score(X_train,y_train)
# Out:
# 0.4724942595995213

# %%
# Lasso R-square
lasso=Lasso(alpha=0.3)
lasso.fit(X_train, y_train)
lasso.score(X_train, y_train)
# Out:
# 0.5275861106431707

# %% [markdown]
# ## 2. statsmodel OLS

# %%
import statsmodels.api as sm

# %%
data2 = data.drop(['s1'], axis=1)
data2.columns
# Out:
# Index(['age', 'bmi', 'bp', 's2', 's3', 's4', 's5', 's6', 'target', 'sex0',
#        'sex1'],
#       dtype='object')

# %%
X2 = data2.drop(["target"], axis=1)
y = data2.target

# %%
model = sm.OLS(y, X2)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     50.71
# Date:                Sat, 24 Jul 2021   Prob (F-statistic):           3.06e-62
# Time:                        10:41:35   Log-Likelihood:                -2387.8
# No. Observations:                 442   AIC:                             4796.
# Df Residuals:                     432   BIC:                             4837.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age           -7.9167     59.920     -0.132      0.895    -125.687     109.853
# bmi          528.5262     66.577      7.939      0.000     397.671     659.381
# bp           319.7704     65.574      4.876      0.000     190.886     448.655
# s2          -143.2835     92.922     -1.542      0.124    -325.919      39.353
# s3          -250.5987    105.002     -2.387      0.017    -456.977     -44.220
# s4            70.4507    151.883      0.464      0.643    -228.071     368.972
# s5           461.8402     80.068      5.768      0.000     304.469     619.211
# s6            69.1260     66.179      1.045      0.297     -60.947     199.199
# sex0         162.5867      3.765     43.188      0.000     155.187     169.986
# sex1         140.2663      4.042     34.702      0.000     132.322     148.211
# ==============================================================================
# Omnibus:                        1.853   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.396   Jarque-Bera (JB):                1.680
# Skew:                           0.044   Prob(JB):                        0.432
# Kurtosis:                       2.711   Cond. No.                         54.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### backward

# %%
# p-value 값이 큰 age 변수 제거해보기 
X3 = X2.drop(["age"], axis=1)
y = data2.target

# %%
model = sm.OLS(y, X3)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     57.17
# Date:                Sat, 24 Jul 2021   Prob (F-statistic):           3.94e-63
# Time:                        10:41:35   Log-Likelihood:                -2387.8
# No. Observations:                 442   AIC:                             4794.
# Df Residuals:                     433   BIC:                             4831.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bmi          528.5663     66.501      7.948      0.000     397.862     659.271
# bp           318.1274     64.311      4.947      0.000     191.726     444.529
# s2          -144.3594     92.460     -1.561      0.119    -326.085      37.366
# s3          -251.1961    104.785     -2.397      0.017    -457.148     -45.245
# s4            70.8996    151.672      0.467      0.640    -227.206     369.005
# s5           460.8097     79.597      5.789      0.000     304.366     617.254
# s6            67.9726     65.526      1.037      0.300     -60.816     196.761
# sex0         162.6229      3.750     43.362      0.000     155.252     169.994
# sex1         140.2252      4.025     34.835      0.000     132.313     148.137
# ==============================================================================
# Omnibus:                        1.879   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.391   Jarque-Bera (JB):                1.701
# Skew:                           0.046   Prob(JB):                        0.427
# Kurtosis:                       2.710   Cond. No.                         54.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# p-value 값이 큰 s4 변수 제거해보기 
X4 = X3.drop(["s4"], axis=1)
y = data2.target

# %%
model = sm.OLS(y, X4)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     65.43
# Date:                Sat, 24 Jul 2021   Prob (F-statistic):           5.22e-64
# Time:                        10:41:35   Log-Likelihood:                -2388.0
# No. Observations:                 442   AIC:                             4792.
# Df Residuals:                     434   BIC:                             4825.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bmi          527.0136     66.358      7.942      0.000     396.591     657.437
# bp           315.4537     63.999      4.929      0.000     189.668     441.240
# s2          -110.9263     58.542     -1.895      0.059    -225.988       4.135
# s3          -289.4064     65.502     -4.418      0.000    -418.148    -160.665
# s5           479.2277     69.098      6.935      0.000     343.419     615.037
# s6            70.0780     65.312      1.073      0.284     -58.290     198.446
# sex0         162.5392      3.743     43.428      0.000     155.183     169.895
# sex1         140.3202      4.017     34.934      0.000     132.426     148.215
# ==============================================================================
# Omnibus:                        1.821   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.402   Jarque-Bera (JB):                1.650
# Skew:                           0.040   Prob(JB):                        0.438
# Kurtosis:                       2.712   Cond. No.                         22.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# * 익스트림하게 좋아지지는 않네요 ㅜㅜ
# * 그치만 모델 성능 지표들이 비슷한 상황이면, 간단한 모델이 제일 베스트겠죠..??

# %% [markdown]
# ## 회귀분석 가정 검토

# %%
import scipy.stats

# %%
# 모델을 통해 얻은 예측값 
pred = result.predict()

# %%
# 잔차 = 실제값 - 예측값 
residual = data['target'] - result.predict()

# %%
sr = scipy.stats.zscore(residual)
(x, y), _ = scipy.stats.probplot(sr)

# %%
# 잔차의 정규성 
sns.scatterplot(x, y)
plt.plot([-3, 3], [-3, 3], '--', color='grey')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Normal Q-Q Plot을 그려 보았을 때, 잔차가 직선의 형태를 아주 잘 따라가고 있으므로
# * 잔차의 정규성을 만족하는 것으로 보입니다 !

# %%
# 잔차의 등분산성 
sns.regplot(pred, np.sqrt(np.abs(sr)), lowess=True, line_kws={'color': 'red'})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * 잔차가 나름 고르게 흩어져 있는 것으로 보아 등분산성도 어느정도 만족한다고 볼 수 있어요
# * 원래 이상적으로 만족하는 경우.. 빨간선이 수평이 된다고 합니다 ^_ㅠ
